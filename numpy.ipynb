# %%
import numpy as np
c=np.array([1,2])
print(c)
# Out:
# [1 2]

# %%
import numpy as cp
e=cp.array([[[1,2,9]]])
print(e)
# Out:
# [[[1 2 9]]]

# %% [markdown]
# # numpy

# %% [markdown]
# ## numpy

# %% [markdown]
# ### numpy

# %% [markdown]
# #### numpy
